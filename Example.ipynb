# %% [markdown]
# NOTEBOOK EXAMPLE
# ================

# %% [markdown]
# You can insert links to webpages: http://www.damian.oquanta.info/categories/vIPer.html
#
# And also you can insert videos:

# %% [markdown]
# .. raw:: html
#
#    <iframe width="420" height="315" src="http://www.youtube.com/embed/n5IWwJnWkzQ" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# Presenter Notes
# ---------------

# %% [markdown]
# You can see all I wrote below "Presenter Notes" ONLY in the presentation mode of slideshow view.

# %% [markdown]
# ----

# %% [markdown]
# Code
# ----

# %%
2+200
# Out:
# 202

# %%
b = "hELLO!"

# %%
b
# Out:
# 'hELLO!'

# %% [markdown]
# Presenter Notes
# ---------------

# %% [markdown]
# Some code... color code by pygments

# %% [markdown]
# ----

# %% [markdown]
# You can insert Latex expressions
# --------------------------------

# %% [markdown]
# A little one...

# %% [markdown]
# $$\\int {a} {b}$$

# %% [markdown]
# .notes: Voila!!! (pressing number "2").

# %% [markdown]
# Presenter Notes
# ---------------

# %% [markdown]
# Powered by MathJax

# %% [markdown]
# ----

# %% [markdown]
# Or you can view plots
# ---------------------

# %%
x = linspace(0, 3*pi, 500)
plt.plot(x, sin(x**2))
title('A simple chirp');

# %% [markdown]
# Presenter Notes
# ---------------

# %% [markdown]
# Last slide...
